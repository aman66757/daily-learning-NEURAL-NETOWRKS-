# %% [markdown]
# Gradient Descent Implementation Python
#
# For employee's bonus dataset, implement gradient descent in PyTorch to find optimal values of weights that decides the bonus amount.

# %%
import pandas as pd
import torch
from matplotlib import pyplot as plt

df = pd.read_csv('bonus_dataset.csv')
df.head()
# Out:
#   employee_id  performance  years_of_experience  projects_completed  bonus
# 0     EMP_001            7                    2                   4    124
# 1     EMP_002            4                    1                   4     82
# 2     EMP_003            8                    7                  10    178
# 3     EMP_004            5                    7                   8    138
# 4     EMP_005            7                    8                   9    170

# %%
df.shape
# Out:
# (100, 5)

# %%
performance = torch.tensor(df['performance'].values, dtype=torch.float32)
years_of_experience = torch.tensor(df['years_of_experience'].values, dtype=torch.float32)
projects_completed = torch.tensor(df['projects_completed'].values, dtype=torch.float32)
bonus = torch.tensor(df['bonus'].values, dtype=torch.float32)

# %% [markdown]
# batch gradient desecent

# %%
w1 = torch.rand(1, requires_grad=True)
w2 = torch.rand(1, requires_grad=True)
w3 = torch.rand(1, requires_grad=True)
bias = torch.rand(1, requires_grad=True)

w1, w2
# Out:
# (tensor([0.3612], requires_grad=True), tensor([0.2281], requires_grad=True))

# %%
learning_rate = 0.006
epochs = 5000


for epoch in range(epochs):
    predicted_bonus = w1 * performance + w2 * years_of_experience + w3 * projects_completed + bias
    loss = ((predicted_bonus - bonus) ** 2).mean() 
    loss.backward()
    with torch.no_grad():
        w1 -= learning_rate * w1.grad
        w2 -= learning_rate * w2.grad
        w3 -= learning_rate * w3.grad
        bias -= learning_rate * bias.grad

    w1.grad.zero_()
    w2.grad.zero_()
    w3.grad.zero_()
    bias.grad.zero_()

    if (epoch + 1) % 100 == 0:
        print(f"Epoch [{epoch + 1}/{epochs}], Loss: {loss.item():.4f}")
# Out:
# Epoch [100/5000], Loss: 17.7603
# Epoch [200/5000], Loss: 15.5000
# Epoch [300/5000], Loss: 13.5275
# Epoch [400/5000], Loss: 11.8061
# Epoch [500/5000], Loss: 10.3037
# Epoch [600/5000], Loss: 8.9925
# Epoch [700/5000], Loss: 7.8481
# Epoch [800/5000], Loss: 6.8494
# Epoch [900/5000], Loss: 5.9778
# Epoch [1000/5000], Loss: 5.2171
# Epoch [1100/5000], Loss: 4.5532
# Epoch [1200/5000], Loss: 3.9738
# Epoch [1300/5000], Loss: 3.4681
# Epoch [1400/5000], Loss: 3.0267
# Epoch [1500/5000], Loss: 2.6416
# Epoch [1600/5000], Loss: 2.3054
# Epoch [1700/5000], Loss: 2.0120
# Epoch [1800/5000], Loss: 1.7560
# Epoch [1900/5000], Loss: 1.5325
# Epoch [2000/5000], Loss: 1.3375
# Epoch [2100/5000], Loss: 1.1673
# Epoch [2200/5000], Loss: 1.0188
# Epoch [2300/5000], Loss: 0.8891
# Epoch [2400/5000], Loss: 0.7760
# Epoch [2500/5000], Loss: 0.6772
# Epoch [2600/5000], Loss: 0.5910
# Epoch [2700/5000], Loss: 0.5158
# Epoch [2800/5000], Loss: 0.4502
# Epoch [2900/5000], Loss: 0.3929
# Epoch [3000/5000], Loss: 0.3429
# Epoch [3100/5000], Loss: 0.2993
# Epoch [3200/5000], Loss: 0.2612
# Epoch [3300/5000], Loss: 0.2279
# Epoch [3400/5000], Loss: 0.1989
# Epoch [3500/5000], Loss: 0.1736
# Epoch [3600/5000], Loss: 0.1515
# Epoch [3700/5000], Loss: 0.1322
# Epoch [3800/5000], Loss: 0.1154
# Epoch [3900/5000], Loss: 0.1007
# Epoch [4000/5000], Loss: 0.0879
# Epoch [4100/5000], Loss: 0.0767
# Epoch [4200/5000], Loss: 0.0670
# Epoch [4300/5000], Loss: 0.0584
# Epoch [4400/5000], Loss: 0.0510
# Epoch [4500/5000], Loss: 0.0445
# Epoch [4600/5000], Loss: 0.0388
# Epoch [4700/5000], Loss: 0.0339
# Epoch [4800/5000], Loss: 0.0296
# Epoch [4900/5000], Loss: 0.0258
# Epoch [5000/5000], Loss: 0.0225

# %%
print(f"\nLearned weights and bias:")
print(f"w1: {w1.item():.2f}, w2: {w2.item():.2f}, w3: {w3.item():.2f}, bias: {bias.item():.2f}")
# Out:
# Learned weights and bias:
# w1: 12.03, w2: 5.91, w3: 2.12, bias: 19.39

# %%
predicted_bonus = w1 * 7 + w2 * 4 + w3 * 7 + bias
predicted_bonus
# Out:
# tensor([142.0810], grad_fn=<AddBackward0>)
